# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
from scipy import signal
import xesmf as xe
from keras.models import load_model
 
from mlprecip_utils import *
from mlprecip_models import *
from mlprecip_xai import *
from mlprecip_plot import *

import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.
# /homes/kpegion/.conda/envs/ml-precip/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /homes/kpegion/.conda/envs/ml-precip/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /homes/kpegion/.conda/envs/ml-precip/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /homes/kpegion/.conda/envs/ml-precip/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /homes/kpegion/.conda/envs/ml-precip/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /homes/kpegion/.conda/envs/ml-precip/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
target_dataset='era5-precip'
#target_dataset='era-interim-precip'

varname='precip'
model_type='logmodel_med'
nmodels=100
model_path='../data/cnn/'+target_dataset+'/models/seus.median'
pad_length=10
winter=[12,1,2]
summer=[6,7,8]
cat_labels=['Negative','Positive']

# %% [markdown]
# ### Read in train and test data

# %%
ds_features_tval=xr.open_dataset('../data/cnn/features_trainval.nc')
ds_target_tval=xr.open_dataset('../data/cnn/'+target_dataset+'/target_trainval.nc')
ds_features_test=xr.open_dataset('../data/cnn/features_test.nc')
ds_target_test=xr.open_dataset('../data/cnn/'+target_dataset+'/target_test.nc')

# %%
ds_features=[ds_features_tval,ds_features_test]
ds_target=[ds_target_tval,ds_target_test]

# %%
ds_features
# Out:
# [<xarray.Dataset>
#  Dimensions:    (time: 55520, lat: 37, lon: 72)
#  Coordinates:
#      level      float32 ...
#    * lon        (lon) int64 0 5 10 15 20 25 30 35 ... 325 330 335 340 345 350 355
#    * lat        (lat) int64 -90 -85 -80 -75 -70 -65 -60 ... 60 65 70 75 80 85 90
#    * time       (time) datetime64[ns] 1979-01-01 ... 2016-12-31T18:00:00
#      dayofyear  (time) int64 ...
#  Data variables:
#      z500       (time, lat, lon) float64 ...
#      z850       (time, lat, lon) float64 ...
#      u200       (time, lat, lon) float64 ...
#      u850       (time, lat, lon) float64 ...
#      olr        (lat, time, lon) float64 ...
#      sst        (time, lat, lon) float64 ...,
#  <xarray.Dataset>
#  Dimensions:    (time: 3892, lat: 37, lon: 72)
#  Coordinates:
#      level      float32 ...
#    * lon        (lon) int64 0 5 10 15 20 25 30 35 ... 325 330 335 340 345 350 355
#    * lat        (lat) int64 -90 -85 -80 -75 -70 -65 -60 ... 60 65 70 75 80 85 90
#    * time       (time) datetime64[ns] 2017-01-01 ... 2019-08-31T18:00:00
#      dayofyear  (time) int64 ...
#  Data variables:
#      z500       (time, lat, lon) float64 ...
#      z850       (time, lat, lon) float64 ...
#      u200       (time, lat, lon) float64 ...
#      u850       (time, lat, lon) float64 ...
#      olr        (lat, time, lon) float64 ...
#      sst        (time, lat, lon) float64 ...]

# %% [markdown]
# ### Main Program to Validate Models

# %%
# Loop over seasons
#for seas,slabel,seas_abbrv in zip([winter,summer],['Winter','Summer'],['DJF','JJA']):
for seas,slabel,seas_abbrv in zip([winter,summer],['Summer'],['JJA']):

    print(slabel)
    
    # Loop over Train-Val and Test
    for (ds_f, ds_t,label) in zip(ds_features, ds_target,['Train-Val','Test']):

        ds_f_subset=ds_f
        
        
        # Make sure we have the same times for target and features
        ds_t,ds_f=xr.align(ds_t.dropna(dim='time'),
                           ds_f_subset.dropna(dim='time'),
                           join='inner')

        
        # Make sure we have the same times for target and features
        ds_t,ds_f=xr.align(ds_t.dropna(dim='time'),
                           ds_f.dropna(dim='time'),
                           join='inner')
        
        # Select season from target precip anomalies and features
        ds_f_seas=ds_f.sel(time=ds_f['time.month'].isin(seas)) 
        ds_t_seas=ds_t.sel(time=ds_t['time.month'].isin(seas)) 
        
        # Subtract the median to ensure data is centered and classes are equal
        median=np.percentile(ds_t_seas[varname],50)
        ds_t_seas[varname]=ds_t_seas[varname]-median
       
        # Create X Features input
        feature_vars=list(ds_f_seas.keys())
        X_pad=ds_f_seas.to_stacked_array('features',sample_dims=['time']).values
        
        # One Hot Encode Target (Y)
        Y_ohe=make_ohe_thresh_med(ds_t_seas[varname])
    
        print('Check Features and Target Dimensions')
        print('Features (X): ',X_pad.shape)
        print('Target (Y): ',Y_ohe.shape)
        
        # Loop over Models
        for imodel in range(0,nmodels):
            
            model_infname=model_path+'.'+seas_abbrv+'.'+model_type+'.'+str(imodel)+'.h5'
            print(model_infname)
            model=load_model(model_infname)
            print(model)
            #model.summary()
            
            # Accuracy Score
            score=model.evaluate(X_pad,Y_ohe) 
            print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
            
            # Predictions
            Yprobs=model.predict(X_pad)
            Ypred=np.argmax(Yprobs, axis = 1)
            
            ds_pred=xr.DataArray(Ypred,coords={'time':ds_f_seas['time']},
                                 dims=['time']).to_dataset(name='pred')
    
            ds_probs=xr.DataArray(Yprobs,coords={'time':ds_f_seas['time'],
                                                 'cat':cat_labels},
                                        dims=['time','cat']).to_dataset(name='probs')
            ds_acc=xr.DataArray(score[1],
                                coords={'model':[imodel]},
                                dims=['model']).to_dataset(name='acc')    
            ds_verif=xr.DataArray(np.argmax(Y_ohe,axis=1),
                                  coords={'time':ds_f_seas['time']},
                                  dims=['time']).to_dataset(name='verif')
          
            #ds=xr.merge([ds_lrp,ds_pred,ds_verif,ds_probs,ds_acc])
            ds=xr.merge([ds_pred,ds_verif,ds_probs,ds_acc])
            
            #del ds_lrp,ds_pred,ds_verif,ds_probs,ds_acc
            del ds_pred,ds_verif,ds_probs,ds_acc
            
            model_ofname='../data/cnn/'+target_dataset+'/validate/model_validate.'+label+'.'+seas_abbrv+'.'+model_type+'.'+str(imodel)+'.nc'
            ds.to_netcdf(model_ofname)
# Out:
# Summer
# Upper Cat:  1715
# Lower Cat:  1715
# Check Features and Target Dimensions
# Features (X):  (3430, 15984)
# Target (Y):  (3430, 2)
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.0.h5
# <keras.engine.sequential.Sequential object at 0x7f005c514410>
# 3430/3430 [==============================] - 0s 73us/step
# acc: 64.37%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.1.h5
# <keras.engine.sequential.Sequential object at 0x7f00776fda50>
# 3430/3430 [==============================] - 0s 65us/step
# acc: 61.43%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.2.h5
# <keras.engine.sequential.Sequential object at 0x7f00777e4e90>
# 3430/3430 [==============================] - 0s 73us/step
# acc: 62.39%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.3.h5
# <keras.engine.sequential.Sequential object at 0x7f007790b850>
# 3430/3430 [==============================] - 0s 100us/step
# acc: 61.43%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.4.h5
# <keras.engine.sequential.Sequential object at 0x7f005771aa50>
# 3430/3430 [==============================] - 0s 79us/step
# acc: 61.28%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.5.h5
# <keras.engine.sequential.Sequential object at 0x7f00572dda90>
# 3430/3430 [==============================] - 0s 80us/step
# acc: 63.70%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.6.h5
# <keras.engine.sequential.Sequential object at 0x7f00572464d0>
# 3430/3430 [==============================] - 0s 83us/step
# acc: 63.12%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.7.h5
# <keras.engine.sequential.Sequential object at 0x7f0056e53550>
# 3430/3430 [==============================] - 0s 75us/step
# acc: 61.52%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.8.h5
# <keras.engine.sequential.Sequential object at 0x7f00566a2d10>
# 3430/3430 [==============================] - 0s 87us/step
# acc: 60.26%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.9.h5
# <keras.engine.sequential.Sequential object at 0x7f0056272a50>
# 3430/3430 [==============================] - 0s 93us/step
# acc: 59.91%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.10.h5
# <keras.engine.sequential.Sequential object at 0x7f00561daa10>
# 3430/3430 [==============================] - 0s 97us/step
# acc: 59.77%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.11.h5
# <keras.engine.sequential.Sequential object at 0x7f0055d840d0>
# 3430/3430 [==============================] - 0s 100us/step
# acc: 59.21%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.12.h5
# <keras.engine.sequential.Sequential object at 0x7f00559afa50>
# 3430/3430 [==============================] - 0s 102us/step
# acc: 58.95%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.13.h5
# <keras.engine.sequential.Sequential object at 0x7f0055208d50>
# 3430/3430 [==============================] - 0s 96us/step
# acc: 57.67%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.14.h5
# <keras.engine.sequential.Sequential object at 0x7f0054e31f10>
# 3430/3430 [==============================] - 0s 109us/step
# acc: 58.72%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.15.h5
# <keras.engine.sequential.Sequential object at 0x7f005494dd90>
# 3430/3430 [==============================] - 0s 104us/step
# acc: 61.55%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.16.h5
# <keras.engine.sequential.Sequential object at 0x7f0054915210>
# 3430/3430 [==============================] - 0s 107us/step
# acc: 61.20%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.17.h5
# <keras.engine.sequential.Sequential object at 0x7f00541ae4d0>
# 3430/3430 [==============================] - 0s 111us/step
# acc: 60.87%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.18.h5
# <keras.engine.sequential.Sequential object at 0x7f0053d8bf90>
# 3430/3430 [==============================] - 0s 128us/step
# acc: 62.33%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.19.h5
# <keras.engine.sequential.Sequential object at 0x7f00538c5dd0>
# 3430/3430 [==============================] - 0s 131us/step
# acc: 58.72%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.20.h5
# <keras.engine.sequential.Sequential object at 0x7f005385ccd0>
# 3430/3430 [==============================] - 0s 132us/step
# acc: 60.55%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.21.h5
# <keras.engine.sequential.Sequential object at 0x7f005340dd90>
# 3430/3430 [==============================] - 0s 135us/step
# acc: 59.74%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.22.h5
# <keras.engine.sequential.Sequential object at 0x7f0053039410>
# 3430/3430 [==============================] - 0s 141us/step
# acc: 59.97%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.23.h5
# <keras.engine.sequential.Sequential object at 0x7f0052bd88d0>
# 3430/3430 [==============================] - 1s 163us/step
# acc: 60.17%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.24.h5
# <keras.engine.sequential.Sequential object at 0x7f005242a450>
# 3430/3430 [==============================] - 1s 162us/step
# acc: 58.92%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.25.h5
# <keras.engine.sequential.Sequential object at 0x7f0052392a50>
# 3430/3430 [==============================] - 0s 145us/step
# acc: 61.98%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.26.h5
# <keras.engine.sequential.Sequential object at 0x7f0051bd2cd0>
# 3430/3430 [==============================] - 1s 165us/step
# acc: 60.23%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.27.h5
# <keras.engine.sequential.Sequential object at 0x7f0051870f90>
# 3430/3430 [==============================] - 1s 152us/step
# acc: 62.45%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.28.h5
# <keras.engine.sequential.Sequential object at 0x7f0051733150>
# 3430/3430 [==============================] - 1s 165us/step
# acc: 60.06%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.29.h5
# <keras.engine.sequential.Sequential object at 0x7f00512c3d10>
# 3430/3430 [==============================] - 1s 172us/step
# acc: 58.72%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.30.h5
# <keras.engine.sequential.Sequential object at 0x7f00268a5dd0>
# 3430/3430 [==============================] - 1s 175us/step
# acc: 59.83%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.31.h5
# <keras.engine.sequential.Sequential object at 0x7f0026497950>
# 3430/3430 [==============================] - 1s 188us/step
# acc: 61.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.32.h5
# <keras.engine.sequential.Sequential object at 0x7f0026138f90>
# 3430/3430 [==============================] - 1s 176us/step
# acc: 59.45%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.33.h5
# <keras.engine.sequential.Sequential object at 0x7f0025d419d0>
# 3430/3430 [==============================] - 1s 180us/step
# acc: 58.31%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.34.h5
# <keras.engine.sequential.Sequential object at 0x7f0025c0acd0>
# 3430/3430 [==============================] - 1s 192us/step
# acc: 59.62%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.35.h5
# <keras.engine.sequential.Sequential object at 0x7f00257ba6d0>
# 3430/3430 [==============================] - 1s 195us/step
# acc: 60.29%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.36.h5
# <keras.engine.sequential.Sequential object at 0x7f0025364c50>
# 3430/3430 [==============================] - 1s 190us/step
# acc: 61.95%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.37.h5
# <keras.engine.sequential.Sequential object at 0x7f0024f14650>
# 3430/3430 [==============================] - 1s 211us/step
# acc: 57.38%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.38.h5
# <keras.engine.sequential.Sequential object at 0x7f0024b3cc50>
# 3430/3430 [==============================] - 1s 200us/step
# acc: 58.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.39.h5
# <keras.engine.sequential.Sequential object at 0x7f00246e80d0>
# 3430/3430 [==============================] - 1s 226us/step
# acc: 59.07%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.40.h5
# <keras.engine.sequential.Sequential object at 0x7f00242954d0>
# 3430/3430 [==============================] - 1s 226us/step
# acc: 60.52%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.41.h5
# <keras.engine.sequential.Sequential object at 0x7f001fac4d50>
# 3430/3430 [==============================] - 1s 221us/step
# acc: 62.16%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.42.h5
# <keras.engine.sequential.Sequential object at 0x7f001f737d10>
# 3430/3430 [==============================] - 1s 238us/step
# acc: 58.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.43.h5
# <keras.engine.sequential.Sequential object at 0x7f001f359f90>
# 3430/3430 [==============================] - 1s 239us/step
# acc: 60.03%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.44.h5
# <keras.engine.sequential.Sequential object at 0x7f001eef0e90>
# 3430/3430 [==============================] - 1s 244us/step
# acc: 62.54%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.45.h5
# <keras.engine.sequential.Sequential object at 0x7f001ea56410>
# 3430/3430 [==============================] - 1s 249us/step
# acc: 59.07%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.46.h5
# <keras.engine.sequential.Sequential object at 0x7f001e9d4750>
# 3430/3430 [==============================] - 1s 246us/step
# acc: 57.20%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.47.h5
# <keras.engine.sequential.Sequential object at 0x7f001e272cd0>
# 3430/3430 [==============================] - 1s 253us/step
# acc: 63.00%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.48.h5
# <keras.engine.sequential.Sequential object at 0x7f001e1b2b10>
# 3430/3430 [==============================] - 1s 266us/step
# acc: 59.42%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.49.h5
# <keras.engine.sequential.Sequential object at 0x7f001dd60650>
# 3430/3430 [==============================] - 1s 271us/step
# acc: 60.93%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.50.h5
# <keras.engine.sequential.Sequential object at 0x7f001d90aa10>
# 3430/3430 [==============================] - 1s 281us/step
# acc: 60.09%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.51.h5
# <keras.engine.sequential.Sequential object at 0x7f001d537390>
# 3430/3430 [==============================] - 1s 284us/step
# acc: 60.06%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.52.h5
# <keras.engine.sequential.Sequential object at 0x7f001d0e7c10>
# 3430/3430 [==============================] - 1s 290us/step
# acc: 60.64%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.53.h5
# <keras.engine.sequential.Sequential object at 0x7f001ccf9f10>
# 3430/3430 [==============================] - 1s 294us/step
# acc: 61.31%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.54.h5
# <keras.engine.sequential.Sequential object at 0x7eff88bd2990>
# 3430/3430 [==============================] - 1s 298us/step
# acc: 59.33%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.55.h5
# <keras.engine.sequential.Sequential object at 0x7eff88bbc110>
# 3430/3430 [==============================] - 1s 312us/step
# acc: 58.83%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.56.h5
# <keras.engine.sequential.Sequential object at 0x7eff88769690>
# 3430/3430 [==============================] - 1s 311us/step
# acc: 60.00%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.57.h5
# <keras.engine.sequential.Sequential object at 0x7eff8802bed0>
# 3430/3430 [==============================] - 1s 320us/step
# acc: 59.07%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.58.h5
# <keras.engine.sequential.Sequential object at 0x7eff7bf32990>
# 3430/3430 [==============================] - 1s 315us/step
# acc: 58.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.59.h5
# <keras.engine.sequential.Sequential object at 0x7eff7b70c490>
# 3430/3430 [==============================] - 1s 319us/step
# acc: 60.73%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.60.h5
# <keras.engine.sequential.Sequential object at 0x7eff7b6f6ed0>
# 3430/3430 [==============================] - 1s 336us/step
# acc: 60.99%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.61.h5
# <keras.engine.sequential.Sequential object at 0x7eff7b2b4650>
# 3430/3430 [==============================] - 1s 344us/step
# acc: 60.61%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.62.h5
# <keras.engine.sequential.Sequential object at 0x7eff7ab34ed0>
# 3430/3430 [==============================] - 1s 349us/step
# acc: 57.99%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.63.h5
# <keras.engine.sequential.Sequential object at 0x7eff7aa15310>
# 3430/3430 [==============================] - 1s 382us/step
# acc: 60.96%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.64.h5
# <keras.engine.sequential.Sequential object at 0x7eff7a5c5550>
# 3430/3430 [==============================] - 1s 365us/step
# acc: 59.65%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.65.h5
# <keras.engine.sequential.Sequential object at 0x7eff7a1e2250>
# 3430/3430 [==============================] - 1s 370us/step
# acc: 60.20%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.66.h5
# <keras.engine.sequential.Sequential object at 0x7eff79a0c950>
# 3430/3430 [==============================] - 1s 375us/step
# acc: 59.53%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.67.h5
# <keras.engine.sequential.Sequential object at 0x7eff799a86d0>
# 3430/3430 [==============================] - 1s 386us/step
# acc: 60.20%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.68.h5
# <keras.engine.sequential.Sequential object at 0x7eff79561190>
# 3430/3430 [==============================] - 1s 394us/step
# acc: 59.36%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.69.h5
# <keras.engine.sequential.Sequential object at 0x7eff78dcc690>
# 3430/3430 [==============================] - 1s 408us/step
# acc: 60.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.70.h5
# <keras.engine.sequential.Sequential object at 0x7eff789fac50>
# 3430/3430 [==============================] - 1s 403us/step
# acc: 63.15%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.71.h5
# <keras.engine.sequential.Sequential object at 0x7eff785c6ed0>
# 3430/3430 [==============================] - 1s 417us/step
# acc: 60.67%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.72.h5
# <keras.engine.sequential.Sequential object at 0x7eff78182d90>
# 3430/3430 [==============================] - 1s 426us/step
# acc: 60.99%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.73.h5
# <keras.engine.sequential.Sequential object at 0x7eff77d28490>
# 3430/3430 [==============================] - 1s 429us/step
# acc: 60.32%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.74.h5
# <keras.engine.sequential.Sequential object at 0x7eff77c95f50>
# 3430/3430 [==============================] - 1s 437us/step
# acc: 62.39%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.75.h5
# <keras.engine.sequential.Sequential object at 0x7eff77852950>
# 3430/3430 [==============================] - 2s 442us/step
# acc: 59.39%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.76.h5
# <keras.engine.sequential.Sequential object at 0x7eff770d4e90>
# 3430/3430 [==============================] - 2s 441us/step
# acc: 61.28%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.77.h5
# <keras.engine.sequential.Sequential object at 0x7eff77035290>
# 3430/3430 [==============================] - 2s 466us/step
# acc: 60.61%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.78.h5
# <keras.engine.sequential.Sequential object at 0x7eff76bce2d0>
# 3430/3430 [==============================] - 2s 453us/step
# acc: 61.28%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.79.h5
# <keras.engine.sequential.Sequential object at 0x7eff47ee8a90>
# 3430/3430 [==============================] - 2s 457us/step
# acc: 60.61%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.80.h5
# <keras.engine.sequential.Sequential object at 0x7eff47aed950>
# 3430/3430 [==============================] - 2s 478us/step
# acc: 60.09%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.81.h5
# <keras.engine.sequential.Sequential object at 0x7eff47a0fb50>
# 3430/3430 [==============================] - 2s 486us/step
# acc: 62.27%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.82.h5
# <keras.engine.sequential.Sequential object at 0x7eff472686d0>
# 3430/3430 [==============================] - 2s 487us/step
# acc: 60.82%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.83.h5
# <keras.engine.sequential.Sequential object at 0x7eff542badd0>
# 3430/3430 [==============================] - 2s 487us/step
# acc: 60.87%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.84.h5
# <keras.engine.sequential.Sequential object at 0x7eff46d868d0>
# 3430/3430 [==============================] - 2s 512us/step
# acc: 61.81%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.85.h5
# <keras.engine.sequential.Sequential object at 0x7eff469411d0>
# 3430/3430 [==============================] - 2s 510us/step
# acc: 56.06%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.86.h5
# <keras.engine.sequential.Sequential object at 0x7eff46557050>
# 3430/3430 [==============================] - 2s 519us/step
# acc: 58.40%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.87.h5
# <keras.engine.sequential.Sequential object at 0x7eff46105c10>
# 3430/3430 [==============================] - 2s 527us/step
# acc: 62.80%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.88.h5
# <keras.engine.sequential.Sequential object at 0x7eff45968d10>
# 3430/3430 [==============================] - 2s 538us/step
# acc: 60.96%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.89.h5
# <keras.engine.sequential.Sequential object at 0x7eff458f1c90>
# 3430/3430 [==============================] - 2s 546us/step
# acc: 61.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.90.h5
# <keras.engine.sequential.Sequential object at 0x7eff45134310>
# 3430/3430 [==============================] - 2s 558us/step
# acc: 61.46%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.91.h5
# <keras.engine.sequential.Sequential object at 0x7eff44d39b10>
# 3430/3430 [==============================] - 2s 561us/step
# acc: 61.22%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.92.h5
# <keras.engine.sequential.Sequential object at 0x7eff44932990>
# 3430/3430 [==============================] - 2s 570us/step
# acc: 61.40%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.93.h5
# <keras.engine.sequential.Sequential object at 0x7eff44854710>
# 3430/3430 [==============================] - 2s 578us/step
# acc: 62.54%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.94.h5
# <keras.engine.sequential.Sequential object at 0x7eff4416e550>
# 3430/3430 [==============================] - 2s 589us/step
# acc: 62.77%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.95.h5
# <keras.engine.sequential.Sequential object at 0x7eff440219d0>
# 3430/3430 [==============================] - 2s 581us/step
# acc: 60.35%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.96.h5
# <keras.engine.sequential.Sequential object at 0x7eff4393f190>
# 3430/3430 [==============================] - 2s 590us/step
# acc: 60.82%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.97.h5
# <keras.engine.sequential.Sequential object at 0x7eff4347de10>
# 3430/3430 [==============================] - 2s 599us/step
# acc: 61.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.98.h5
# <keras.engine.sequential.Sequential object at 0x7eff4304ded0>
# 3430/3430 [==============================] - 2s 605us/step
# acc: 58.40%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.99.h5
# <keras.engine.sequential.Sequential object at 0x7eff42c21f10>
# 3430/3430 [==============================] - 2s 618us/step
# acc: 60.90%
# Upper Cat:  120
# Lower Cat:  119
# Check Features and Target Dimensions
# Features (X):  (239, 15984)
# Target (Y):  (239, 2)
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.0.h5
# <keras.engine.sequential.Sequential object at 0x7eff30d32290>
# 239/239 [==============================] - 2s 8ms/step
# acc: 67.36%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.1.h5
# <keras.engine.sequential.Sequential object at 0x7eff30d8efd0>
# 239/239 [==============================] - 2s 8ms/step
# acc: 64.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.2.h5
# <keras.engine.sequential.Sequential object at 0x7f007632add0>
# 239/239 [==============================] - 2s 8ms/step
# acc: 64.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.3.h5
# <keras.engine.sequential.Sequential object at 0x7f0075ed8e50>
# 239/239 [==============================] - 2s 8ms/step
# acc: 66.53%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.4.h5
# <keras.engine.sequential.Sequential object at 0x7f0075761b50>
# 239/239 [==============================] - 2s 8ms/step
# acc: 65.69%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.5.h5
# <keras.engine.sequential.Sequential object at 0x7f007569e790>
# 239/239 [==============================] - 2s 8ms/step
# acc: 64.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.6.h5
# <keras.engine.sequential.Sequential object at 0x7f00752d6f10>
# 239/239 [==============================] - 2s 9ms/step
# acc: 68.20%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.7.h5
# <keras.engine.sequential.Sequential object at 0x7f0074a9f1d0>
# 239/239 [==============================] - 2s 9ms/step
# acc: 64.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.8.h5
# <keras.engine.sequential.Sequential object at 0x7f00746cedd0>
# 239/239 [==============================] - 2s 9ms/step
# acc: 59.41%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.9.h5
# <keras.engine.sequential.Sequential object at 0x7f00743473d0>
# 239/239 [==============================] - 2s 9ms/step
# acc: 63.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.10.h5
# <keras.engine.sequential.Sequential object at 0x7f0073e22510>
# 239/239 [==============================] - 2s 9ms/step
# acc: 64.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.11.h5
# <keras.engine.sequential.Sequential object at 0x7f0073b0f750>
# 239/239 [==============================] - 2s 9ms/step
# acc: 64.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.12.h5
# <keras.engine.sequential.Sequential object at 0x7f007362de50>
# 239/239 [==============================] - 2s 9ms/step
# acc: 60.25%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.13.h5
# <keras.engine.sequential.Sequential object at 0x7f00731a8bd0>
# 239/239 [==============================] - 2s 10ms/step
# acc: 58.16%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.14.h5
# <keras.engine.sequential.Sequential object at 0x7f0072db3a10>
# 239/239 [==============================] - 2s 9ms/step
# acc: 55.23%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.15.h5
# <keras.engine.sequential.Sequential object at 0x7f00729abf90>
# 239/239 [==============================] - 2s 10ms/step
# acc: 65.27%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.16.h5
# <keras.engine.sequential.Sequential object at 0x7f0072590750>
# 239/239 [==============================] - 2s 10ms/step
# acc: 60.67%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.17.h5
# <keras.engine.sequential.Sequential object at 0x7f0072175910>
# 239/239 [==============================] - 2s 10ms/step
# acc: 62.76%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.18.h5
# <keras.engine.sequential.Sequential object at 0x7f0071db5f10>
# 239/239 [==============================] - 2s 10ms/step
# acc: 63.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.19.h5
# <keras.engine.sequential.Sequential object at 0x7f0071cbb550>
# 239/239 [==============================] - 2s 10ms/step
# acc: 62.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.20.h5
# <keras.engine.sequential.Sequential object at 0x7f00715c9550>
# 239/239 [==============================] - 3s 11ms/step
# acc: 67.36%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.21.h5
# <keras.engine.sequential.Sequential object at 0x7f00711524d0>
# 239/239 [==============================] - 3s 11ms/step
# acc: 64.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.22.h5
# <keras.engine.sequential.Sequential object at 0x7f0070d27f90>
# 239/239 [==============================] - 3s 11ms/step
# acc: 59.83%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.23.h5
# <keras.engine.sequential.Sequential object at 0x7f007094c250>
# 239/239 [==============================] - 3s 11ms/step
# acc: 63.18%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.24.h5
# <keras.engine.sequential.Sequential object at 0x7f00707fabd0>
# 239/239 [==============================] - 3s 11ms/step
# acc: 65.27%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.25.h5
# <keras.engine.sequential.Sequential object at 0x7f00700505d0>
# 239/239 [==============================] - 3s 11ms/step
# acc: 62.76%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.26.h5
# <keras.engine.sequential.Sequential object at 0x7f006fbf4750>
# 239/239 [==============================] - 3s 11ms/step
# acc: 64.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.27.h5
# <keras.engine.sequential.Sequential object at 0x7f006fb95290>
# 239/239 [==============================] - 3s 12ms/step
# acc: 64.44%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.28.h5
# <keras.engine.sequential.Sequential object at 0x7f006f3cd950>
# 239/239 [==============================] - 3s 12ms/step
# acc: 67.36%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.29.h5
# <keras.engine.sequential.Sequential object at 0x7f006f00cf50>
# 239/239 [==============================] - 3s 12ms/step
# acc: 61.92%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.30.h5
# <keras.engine.sequential.Sequential object at 0x7f006ef15490>
# 239/239 [==============================] - 3s 12ms/step
# acc: 64.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.31.h5
# <keras.engine.sequential.Sequential object at 0x7f006e7a6210>
# 239/239 [==============================] - 3s 12ms/step
# acc: 59.41%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.32.h5
# <keras.engine.sequential.Sequential object at 0x7f006e2eec50>
# 239/239 [==============================] - 3s 12ms/step
# acc: 59.00%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.33.h5
# <keras.engine.sequential.Sequential object at 0x7f006df50290>
# 239/239 [==============================] - 3s 12ms/step
# acc: 55.65%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.34.h5
# <keras.engine.sequential.Sequential object at 0x7f006db09a10>
# 239/239 [==============================] - 3s 12ms/step
# acc: 63.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.35.h5
# <keras.engine.sequential.Sequential object at 0x7f006d6cd550>
# 239/239 [==============================] - 3s 12ms/step
# acc: 62.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.36.h5
# <keras.engine.sequential.Sequential object at 0x7f006d303c90>
# 239/239 [==============================] - 3s 12ms/step
# acc: 64.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.37.h5
# <keras.engine.sequential.Sequential object at 0x7f006ce2d6d0>
# 239/239 [==============================] - 3s 13ms/step
# acc: 62.76%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.38.h5
# <keras.engine.sequential.Sequential object at 0x7f006ca29810>
# 239/239 [==============================] - 3s 13ms/step
# acc: 62.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.39.h5
# <keras.engine.sequential.Sequential object at 0x7f006c5ab990>
# 239/239 [==============================] - 3s 13ms/step
# acc: 59.41%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.40.h5
# <keras.engine.sequential.Sequential object at 0x7f006c53bc10>
# 239/239 [==============================] - 3s 13ms/step
# acc: 65.69%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.41.h5
# <keras.engine.sequential.Sequential object at 0x7f006bdcadd0>
# 239/239 [==============================] - 3s 13ms/step
# acc: 68.20%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.42.h5
# <keras.engine.sequential.Sequential object at 0x7f006b9ff110>
# 239/239 [==============================] - 3s 13ms/step
# acc: 62.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.43.h5
# <keras.engine.sequential.Sequential object at 0x7f006b4e1b90>
# 239/239 [==============================] - 3s 13ms/step
# acc: 61.51%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.44.h5
# <keras.engine.sequential.Sequential object at 0x7f006b0e7fd0>
# 239/239 [==============================] - 3s 13ms/step
# acc: 63.18%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.45.h5
# <keras.engine.sequential.Sequential object at 0x7f006ace3f50>
# 239/239 [==============================] - 3s 13ms/step
# acc: 59.00%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.46.h5
# <keras.engine.sequential.Sequential object at 0x7f006a918850>
# 239/239 [==============================] - 3s 14ms/step
# acc: 57.74%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.47.h5
# <keras.engine.sequential.Sequential object at 0x7f006a483650>
# 239/239 [==============================] - 3s 14ms/step
# acc: 62.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.48.h5
# <keras.engine.sequential.Sequential object at 0x7f006a060e10>
# 239/239 [==============================] - 3s 14ms/step
# acc: 63.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.49.h5
# <keras.engine.sequential.Sequential object at 0x7f0069cbe550>
# 239/239 [==============================] - 3s 14ms/step
# acc: 62.76%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.50.h5
# <keras.engine.sequential.Sequential object at 0x7f006981b610>
# 239/239 [==============================] - 4s 15ms/step
# acc: 62.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.51.h5
# <keras.engine.sequential.Sequential object at 0x7f006945af10>
# 239/239 [==============================] - 3s 15ms/step
# acc: 65.69%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.52.h5
# <keras.engine.sequential.Sequential object at 0x7f0068ff3dd0>
# 239/239 [==============================] - 4s 15ms/step
# acc: 63.18%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.53.h5
# <keras.engine.sequential.Sequential object at 0x7f0068c51f50>
# 239/239 [==============================] - 4s 15ms/step
# acc: 59.41%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.54.h5
# <keras.engine.sequential.Sequential object at 0x7f0068b38250>
# 239/239 [==============================] - 4s 16ms/step
# acc: 60.67%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.55.h5
# <keras.engine.sequential.Sequential object at 0x7f00683acd90>
# 239/239 [==============================] - 4s 16ms/step
# acc: 58.16%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.56.h5
# <keras.engine.sequential.Sequential object at 0x7f00682fcd10>
# 239/239 [==============================] - 4s 16ms/step
# acc: 63.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.57.h5
# <keras.engine.sequential.Sequential object at 0x7f0067b4ae10>
# 239/239 [==============================] - 4s 16ms/step
# acc: 61.51%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.58.h5
# <keras.engine.sequential.Sequential object at 0x7f006772aed0>
# 239/239 [==============================] - 4s 16ms/step
# acc: 60.25%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.59.h5
# <keras.engine.sequential.Sequential object at 0x7f0067672350>
# 239/239 [==============================] - 4s 16ms/step
# acc: 66.53%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.60.h5
# <keras.engine.sequential.Sequential object at 0x7f0066ecc590>
# 239/239 [==============================] - 4s 16ms/step
# acc: 67.36%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.61.h5
# <keras.engine.sequential.Sequential object at 0x7f0066ddb050>
# 239/239 [==============================] - 4s 16ms/step
# acc: 57.74%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.62.h5
# <keras.engine.sequential.Sequential object at 0x7f00666cb750>
# 239/239 [==============================] - 4s 16ms/step
# acc: 64.44%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.63.h5
# <keras.engine.sequential.Sequential object at 0x7f006626a310>
# 239/239 [==============================] - 4s 16ms/step
# acc: 63.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.64.h5
# <keras.engine.sequential.Sequential object at 0x7f00661d7f50>
# 239/239 [==============================] - 4s 16ms/step
# acc: 60.25%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.65.h5
# <keras.engine.sequential.Sequential object at 0x7f0065d73810>
# 239/239 [==============================] - 4s 17ms/step
# acc: 64.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.66.h5
# <keras.engine.sequential.Sequential object at 0x7f0065622550>
# 239/239 [==============================] - 4s 17ms/step
# acc: 62.34%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.67.h5
# <keras.engine.sequential.Sequential object at 0x7f0065168c10>
# 239/239 [==============================] - 4s 17ms/step
# acc: 64.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.68.h5
# <keras.engine.sequential.Sequential object at 0x7f0064d26e50>
# 239/239 [==============================] - 4s 17ms/step
# acc: 64.02%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.69.h5
# <keras.engine.sequential.Sequential object at 0x7f006492d4d0>
# 239/239 [==============================] - 4s 17ms/step
# acc: 60.67%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.70.h5
# <keras.engine.sequential.Sequential object at 0x7f0064528610>
# 239/239 [==============================] - 4s 18ms/step
# acc: 67.36%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.71.h5
# <keras.engine.sequential.Sequential object at 0x7f00640a45d0>
# 239/239 [==============================] - 4s 17ms/step
# acc: 65.27%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.72.h5
# <keras.engine.sequential.Sequential object at 0x7f0064033150>
# 239/239 [==============================] - 4s 17ms/step
# acc: 62.76%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.73.h5
# <keras.engine.sequential.Sequential object at 0x7f0063c4e9d0>
# 239/239 [==============================] - 4s 18ms/step
# acc: 58.16%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.74.h5
# <keras.engine.sequential.Sequential object at 0x7f0063426950>
# 239/239 [==============================] - 4s 18ms/step
# acc: 64.44%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.75.h5
# <keras.engine.sequential.Sequential object at 0x7f0063063f50>
# 239/239 [==============================] - 4s 18ms/step
# acc: 62.76%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.76.h5
# <keras.engine.sequential.Sequential object at 0x7f0062c46d90>
# 239/239 [==============================] - 4s 18ms/step
# acc: 63.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.77.h5
# <keras.engine.sequential.Sequential object at 0x7f00627e3dd0>
# 239/239 [==============================] - 4s 18ms/step
# acc: 63.18%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.78.h5
# <keras.engine.sequential.Sequential object at 0x7f006235b0d0>
# 239/239 [==============================] - 4s 18ms/step
# acc: 69.46%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.79.h5
# <keras.engine.sequential.Sequential object at 0x7f0061f80210>
# 239/239 [==============================] - 4s 19ms/step
# acc: 67.36%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.80.h5
# <keras.engine.sequential.Sequential object at 0x7f0061b61f50>
# 239/239 [==============================] - 5s 19ms/step
# acc: 59.41%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.81.h5
# <keras.engine.sequential.Sequential object at 0x7f0061723550>
# 239/239 [==============================] - 5s 19ms/step
# acc: 66.53%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.82.h5
# <keras.engine.sequential.Sequential object at 0x7f0061301610>
# 239/239 [==============================] - 5s 19ms/step
# acc: 64.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.83.h5
# <keras.engine.sequential.Sequential object at 0x7f0060ea3790>
# 239/239 [==============================] - 5s 19ms/step
# acc: 65.27%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.84.h5
# <keras.engine.sequential.Sequential object at 0x7f0060aa2c10>
# 239/239 [==============================] - 5s 19ms/step
# acc: 66.53%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.85.h5
# <keras.engine.sequential.Sequential object at 0x7f0060756b50>
# 239/239 [==============================] - 5s 19ms/step
# acc: 64.44%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.86.h5
# <keras.engine.sequential.Sequential object at 0x7f006060f950>
# 239/239 [==============================] - 5s 20ms/step
# acc: 59.83%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.87.h5
# <keras.engine.sequential.Sequential object at 0x7f005fe84c10>
# 239/239 [==============================] - 5s 20ms/step
# acc: 64.44%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.88.h5
# <keras.engine.sequential.Sequential object at 0x7f005fdeed50>
# 239/239 [==============================] - 5s 20ms/step
# acc: 57.32%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.89.h5
# <keras.engine.sequential.Sequential object at 0x7f005f694990>
# 239/239 [==============================] - 5s 20ms/step
# acc: 59.00%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.90.h5
# <keras.engine.sequential.Sequential object at 0x7f005f2a9250>
# 239/239 [==============================] - 5s 20ms/step
# acc: 61.51%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.91.h5
# <keras.engine.sequential.Sequential object at 0x7f005ee2f610>
# 239/239 [==============================] - 5s 20ms/step
# acc: 67.78%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.92.h5
# <keras.engine.sequential.Sequential object at 0x7f005ea10990>
# 239/239 [==============================] - 5s 22ms/step
# acc: 66.11%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.93.h5
# <keras.engine.sequential.Sequential object at 0x7f005e5d3750>
# 239/239 [==============================] - 5s 21ms/step
# acc: 71.13%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.94.h5
# <keras.engine.sequential.Sequential object at 0x7f005e4f4290>
# 239/239 [==============================] - 5s 21ms/step
# acc: 66.53%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.95.h5
# <keras.engine.sequential.Sequential object at 0x7f005ddcf090>
# 239/239 [==============================] - 5s 21ms/step
# acc: 64.85%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.96.h5
# <keras.engine.sequential.Sequential object at 0x7f005d96df50>
# 239/239 [==============================] - 5s 21ms/step
# acc: 63.60%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.97.h5
# <keras.engine.sequential.Sequential object at 0x7f005d8d3d90>
# 239/239 [==============================] - 5s 22ms/step
# acc: 65.69%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.98.h5
# <keras.engine.sequential.Sequential object at 0x7f005d168ed0>
# 239/239 [==============================] - 5s 21ms/step
# acc: 57.74%
# ../data/cnn/era5-precip/models/seus.median.JJA.logmodel_med.99.h5
# <keras.engine.sequential.Sequential object at 0x7f005cc630d0>
# 239/239 [==============================] - 5s 22ms/step
# acc: 67.78%
